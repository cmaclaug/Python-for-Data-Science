# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'https://en.wikipedia.org/wiki/List_of_all-time_NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank    Team       GP  Won  Lost  Tied  Pct.  First   NFL Season Division
# 0     1  Dallas  Cowboys  961   547   408     6  0.572  1960    NFC     East

# %%
nfl_frame.columns
# Out:
# Index([u'Rank', u'Team', u'GP', u'Won', u'Lost', u'Tied', u'Pct.', u'First',
#        u'NFL', u'Season', u'Division'],
#       dtype='object')

# %%
nfl_frame.Team
# Out:
# 0    Dallas
# Name: Team, dtype: object

# %%
nfl_frame['NFL']
# Out:
# 0    1960
# Name: NFL, dtype: int64

# %%
DataFrame(nfl_frame,columns=['Team','GP','NFL'])
# Out:
#      Team       GP   NFL
# 0  Dallas  Cowboys  1960

# %%
DataFrame(nfl_frame,columns=['Team','GP','NFL','Stadium'])
# Out:
#      Team       GP   NFL  Stadium
# 0  Dallas  Cowboys  1960      NaN

# %%
nfl_frame2 = pd.read_clipboard()

# %%
nfl_frame2
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  Season  \
# 0      1           Dallas Cowboys    898  512   380     6  0.573    1960
# 1      2            Chicago Bears  1,386  761   583    42  0.564    1920
# 2      3        Green Bay Packers  1,352  743   571    38  0.564    1921
# 3      4  New England Patriots[b]    900  500   391     9  0.561    1960
# 4      5           Miami Dolphins    816  452   360     4  0.556    1966
# 5      6        Minnesota Vikings    886  478   397    11  0.546    1961
# 6      7         Baltimore Ravens    368  200   167     1  0.545    1996
# 7      8          New York Giants  1,321  692   596    33  0.536    1925
# 8      9           Denver Broncos    900  476   414    10  0.534    1960
# 9     10      San Francisco 49ers  1,018  532   472    14  0.529    1950
# 10    11    Indianapolis Colts[c]    982  516   459     7  0.529    1953
# 11    12      Pittsburgh Steelers  1,208  628   558    22  0.529    1933
# ...

# %%
DataFrame(nfl_frame2,columns=['Team','GP','Season','Division'])
# Out:
#                        Team     GP  Season   Division
# 0            Dallas Cowboys    898    1960   NFC East
# 1             Chicago Bears  1,386    1920  NFC North
# 2         Green Bay Packers  1,352    1921  NFC North
# 3   New England Patriots[b]    900    1960   AFC East
# 4            Miami Dolphins    816    1966   AFC East
# 5         Minnesota Vikings    886    1961  NFC North
# 6          Baltimore Ravens    368    1996  AFC North
# 7           New York Giants  1,321    1925   NFC East
# 8            Denver Broncos    900    1960   AFC West
# 9       San Francisco 49ers  1,018    1950   NFC West
# 10    Indianapolis Colts[c]    982    1953  AFC South
# 11      Pittsburgh Steelers  1,208    1933  AFC North
# 12       Kansas City Chiefs    900    1960   AFC West
# 13          Oakland Raiders    900    1960   AFC West
# 14         Seattle Seahawks    676    1976   NFC West
# 15      Washington Redskins  1,218    1932   NFC East
# ...

# %%
nfl_frame2.head()
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  Season  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573    1960
# 1     2            Chicago Bears  1,386  761   583    42  0.564    1920
# 2     3        Green Bay Packers  1,352  743   571    38  0.564    1921
# 3     4  New England Patriots[b]    900  500   391     9  0.561    1960
# 4     5           Miami Dolphins    816  452   360     4  0.556    1966
#
#     Division
# 0   NFC East
# 1  NFC North
# 2  NFC North
# 3   AFC East
# 4   AFC East

# %%
nfl_frame2.tail()
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  Season  \
# 27    28        Houston Texans    272  121   151     0  0.445    2002
# 28    29  Jacksonville Jaguars    384  170   214     0  0.443    1995
# 29    30       Atlanta Falcons    816  358   452     6  0.442    1966
# 30    31     Arizona Cardinals  1,346  553   753    40  0.426    1920
# 31    32  Tampa Bay Buccaneers    676  260   415     1  0.385    1976
#
#      Division
# 27  AFC South
# 28  AFC South
# 29  NFC South
# 30   NFC West
# 31  NFC South

# %%
nfl_frame2.iloc[3]
# Out:
# Rank                              4
# Team        New England Patriots[b]
# GP                              900
# Won                             500
# Lost                            391
# Tied                              9
# Pct.                          0.561
# Season                         1960
# Division                   AFC East
# Name: 3, dtype: object

# %%
nfl_frame2['Stadium'] = "Levis Stadium"

# %%
nfl_frame2
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  Season  \
# 0      1           Dallas Cowboys    898  512   380     6  0.573    1960
# 1      2            Chicago Bears  1,386  761   583    42  0.564    1920
# 2      3        Green Bay Packers  1,352  743   571    38  0.564    1921
# 3      4  New England Patriots[b]    900  500   391     9  0.561    1960
# 4      5           Miami Dolphins    816  452   360     4  0.556    1966
# 5      6        Minnesota Vikings    886  478   397    11  0.546    1961
# 6      7         Baltimore Ravens    368  200   167     1  0.545    1996
# 7      8          New York Giants  1,321  692   596    33  0.536    1925
# 8      9           Denver Broncos    900  476   414    10  0.534    1960
# 9     10      San Francisco 49ers  1,018  532   472    14  0.529    1950
# 10    11    Indianapolis Colts[c]    982  516   459     7  0.529    1953
# 11    12      Pittsburgh Steelers  1,208  628   558    22  0.529    1933
# ...

# %%
nfl_frame2['Stadium']=np.arange(32)

# %%
nfl_frame2
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  Season  \
# 0      1           Dallas Cowboys    898  512   380     6  0.573    1960
# 1      2            Chicago Bears  1,386  761   583    42  0.564    1920
# 2      3        Green Bay Packers  1,352  743   571    38  0.564    1921
# 3      4  New England Patriots[b]    900  500   391     9  0.561    1960
# 4      5           Miami Dolphins    816  452   360     4  0.556    1966
# 5      6        Minnesota Vikings    886  478   397    11  0.546    1961
# 6      7         Baltimore Ravens    368  200   167     1  0.545    1996
# 7      8          New York Giants  1,321  692   596    33  0.536    1925
# 8      9           Denver Broncos    900  476   414    10  0.534    1960
# 9     10      San Francisco 49ers  1,018  532   472    14  0.529    1950
# 10    11    Indianapolis Colts[c]    982  516   459     7  0.529    1953
# 11    12      Pittsburgh Steelers  1,208  628   558    22  0.529    1933
# ...

# %%
stadiums = Series(["Levis","AT&T"],index=[4,0])

# %%
stadiums
# Out:
# 4    Levis
# 0     AT&T
# dtype: object

# %%
nfl_frame2['Stadiums'] = stadiums

# %%
nfl_frame2
# Out:
#     Rank                     Team     GP  Won  Lost  Tied   Pct.  Season  \
# 0      1           Dallas Cowboys    898  512   380     6  0.573    1960
# 1      2            Chicago Bears  1,386  761   583    42  0.564    1920
# 2      3        Green Bay Packers  1,352  743   571    38  0.564    1921
# 3      4  New England Patriots[b]    900  500   391     9  0.561    1960
# 4      5           Miami Dolphins    816  452   360     4  0.556    1966
# 5      6        Minnesota Vikings    886  478   397    11  0.546    1961
# 6      7         Baltimore Ravens    368  200   167     1  0.545    1996
# 7      8          New York Giants  1,321  692   596    33  0.536    1925
# 8      9           Denver Broncos    900  476   414    10  0.534    1960
# 9     10      San Francisco 49ers  1,018  532   472    14  0.529    1950
# 10    11    Indianapolis Colts[c]    982  516   459     7  0.529    1953
# 11    12      Pittsburgh Steelers  1,208  628   558    22  0.529    1933
# ...

# %%
data = {'City':['SF','LA','NYC'],'Population':[800000,3000000,8000000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      800000
# 1   LA     3000000
# 2  NYC     8000000
